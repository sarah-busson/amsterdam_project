# %%
import pandas as pd
import numpy as np

# %%
# Import the cleaned databases
gg_co2 = pd.read_csv('C:\\Users\\sarah\\Documents\\IRONHACK\\The_Amsterdam_Project\\greenhouse_CO2.txt')

gg_others = pd.read_csv('C:\\Users\\sarah\\Documents\\IRONHACK\\The_Amsterdam_Project\\greenhouse_others.txt')

renewable_energy = pd.read_csv('C:\\Users\\sarah\\Documents\\IRONHACK\\The_Amsterdam_Project\\renewable_energy_data.txt')

gg_co2
gg_others
#renewable_energy
# Out:
#    Year  Total emissions of other greenhouse gases  Total Methane (CH4)  \
# 0  2015                                 32545553.0           21980252.0
# 1  2016                                 31936050.0           22086896.0
# 2  2017                                 32117170.0           21715493.0
# 3  2018                                 31096259.0           21017804.0
#
#    Total F-Gases (HFCs, SF6)  Total Nitrous Oxide (N2O)
# 0                  2292734.0                  8272567.0
# 1                  1881665.0                  7967488.0
# 2                  1843693.0                  8557984.0
# 3                  1881584.0                  8196871.0

# %%
#gg_others['Total emissions of other greenhouse gases'][0]

gg_others['Evolution %'] = ((gg_others['Total emissions of other greenhouse gases'] / gg_others['Total emissions of other greenhouse gases'][0])-1)*100

gg_others = gg_others[['Year', 
                       'Total emissions of other greenhouse gases',
                       'Evolution %', 
                       'Total Methane (CH4)', 
                       'Total F-Gases (HFCs, SF6)', 
                       'Total Nitrous Oxide (N2O)']]

# %%
gg_others
#In 3 years, the total emission of other greenhouse gases (in tons of CO2 equivalent) 
#has reduced by almost 4.5%
# Out:
#    Year  Total emissions of other greenhouse gases  Evolution %  \
# 0  2015                                 32545553.0     0.000000
# 1  2016                                 31936050.0    -1.872769
# 2  2017                                 32117170.0    -1.316257
# 3  2018                                 31096259.0    -4.453125
#
#    Total Methane (CH4)  Total F-Gases (HFCs, SF6)  Total Nitrous Oxide (N2O)
# 0           21980252.0                  2292734.0                  8272567.0
# 1           22086896.0                  1881665.0                  7967488.0
# 2           21715493.0                  1843693.0                  8557984.0
# 3           21017804.0                  1881584.0                  8196871.0

# %%
gg_co2
gg_co2_total = gg_co2[['Year', 
                       'Total CO2 emissions according to Emission Registration (all emission causes) [tons]', 
                       'Total CO2 emissions excluding electricity generation according to ER (all emission causes) [tons]']]

# %%
#gg_co2_total = gg_co2_total.dropna()

#gg_co2_total['Evolution % (all causes)'] = ((gg_co2_total['Total CO2 emissions according to Emission Registration (all emission causes) [tons]'] / gg_co2_total['Total CO2 emissions according to Emission Registration (all emission causes) [tons]'][0])-1)*100
#gg_co2_total['Evolution % (exc. elec generation)'] = ((gg_co2_total['Total CO2 emissions excluding electricity generation according to ER (all emission causes) [tons]'] / gg_co2_total['Total CO2 emissions excluding electricity generation according to ER (all emission causes) [tons]'][0])-1)*100

#gg_co2_total = gg_co2_total.reset_index()
#gg_co2_total.columns
gg_co2_total = gg_co2_total[['Year',
                             'Total CO2 emissions according to Emission Registration (all emission causes) [tons]',
                             'Total CO2 emissions excluding electricity generation according to ER (all emission causes) [tons]',
                             'Evolution % (all causes)', 'Evolution % (exc. elec generation)',
                             'Evolution % (all causes) from 2010',
                             'Evolution % (exc. elec generation) from 2010']]

# %%
#So we actually increased the emissions of CO2, but it was not an increase on long term.
#The pic of pollution seems to be 2010. How did it evolve since that year ?

gg_co2_total['Evolution % (all causes) from 2010'] = ((gg_co2_total['Total CO2 emissions according to Emission Registration (all emission causes) [tons]'] / gg_co2_total['Total CO2 emissions according to Emission Registration (all emission causes) [tons]'][4])-1)*100
gg_co2_total['Evolution % (exc. elec generation) from 2010'] = ((gg_co2_total['Total CO2 emissions excluding electricity generation according to ER (all emission causes) [tons]'] / gg_co2_total['Total CO2 emissions excluding electricity generation according to ER (all emission causes) [tons]'][4])-1)*100

# %%
gg_co2_total
# Out:
#    Year  \
# 0  1990
# 1  1995
# 2  2000
# 3  2005
# 4  2010
# 5  2015
# 6  2016
# 7  2017
# 8  2018
#
#    Total CO2 emissions according to Emission Registration (all emission causes) [tons]  \
# 0                                        169770964.0
# 1                                        180426624.0
# 2                                        180371154.0
# 3                                        189016142.0
# 4                                        197101982.0
# 5                                        184948641.0
# 6                                        186703366.0
# 7                                        183945599.0
# 8                                        179269145.0
#
#    Total CO2 emissions excluding electricity generation according to ER (all emission causes) [tons]  \
# 0                                        129956495.0
# 1                                        137634718.0
# 2                                        133382941.0
# ...

# %%
#NL didn't reduce its emissions of CO2 based on the emissions of the year 1990,
#but it is actually reducing it compared to the emission peak in 2010.

# %%
gg_co2.columns
gg_co2_causes = gg_co2[['Year',
                        'Drinking water supply emissions - CO2 [tons]',
                        'Consumer emissions - CO2 [tons]',
                        'Emissions Trade, Services and Government (HDO) - CO2 [tons]',
                        'Emissions WWTP - CO2 [tons]',
                        'Emissions Traffic and transport - CO2 [tons]',
                        'Emissions Waste Disposal - CO2 [tons]',
                        'Emissions Construction - CO2 [tons]',
                        'Chemical Industry emissions - CO2 [tons]',
                        'Energy sector emissions - CO2 [tons]',
                        'Emissions Other industry - CO2 [tons]',
                        'Refineries emissions - CO2 [tons]',
                        'Agriculture emissions - CO2 [tons]']]

gg_co2_causes = gg_co2_causes.dropna()
gg_co2_causes
# Out:
#     Year  Drinking water supply emissions - CO2 [tons]  \
# 0   1990                                       14541.0
# 5   1995                                       14144.0
# 10  2000                                       31371.0
# 15  2005                                       22805.0
# 20  2010                                       26731.0
# 25  2015                                       10298.0
# 26  2016                                        8855.0
# 27  2017                                        8023.0
# 28  2018                                        6986.0
#
#     Consumer emissions - CO2 [tons]  \
# 0                        22392114.0
# 5                        25068108.0
# 10                       22363194.0
# 15                       21752378.0
# 20                       25395682.0
# 25                       18632625.0
# 26                       19355662.0
# 27                       18925638.0
# 28                       18480105.0
#
# ...

# %%
new_row = {'Year':'Base 1990',
           'Drinking water supply emissions - CO2 [tons]':((gg_co2_causes['Drinking water supply emissions - CO2 [tons]'][28] / gg_co2_causes['Drinking water supply emissions - CO2 [tons]'][0])-1)*100,
           'Consumer emissions - CO2 [tons]':((gg_co2_causes['Consumer emissions - CO2 [tons]'][28] / gg_co2_causes['Consumer emissions - CO2 [tons]'][0])-1)*100,
           'Emissions Trade, Services and Government (HDO) - CO2 [tons]':((gg_co2_causes['Emissions Trade, Services and Government (HDO) - CO2 [tons]'[28]] / gg_co2_causes['Emissions Trade, Services and Government (HDO) - CO2 [tons]'][0])-1)*100,
           'Emissions WWTP - CO2 [tons]':((gg_co2_causes['Emissions WWTP - CO2 [tons]'][28] / gg_co2_causes['Emissions WWTP - CO2 [tons]'][0])-1)*100,
           'Emissions Traffic and transport - CO2 [tons]':((gg_co2_causes['Emissions Traffic and transport - CO2 [tons]'][28] / gg_co2_causes['Emissions Traffic and transport - CO2 [tons]'][0])-1)*100,
           'Emissions Waste Disposal - CO2 [tons]':((gg_co2_causes['Emissions Waste Disposal - CO2 [tons]'][28] / gg_co2_causes['Emissions Waste Disposal - CO2 [tons]'][0])-1)*100,
           'Emissions Construction - CO2 [tons]':((gg_co2_causes['Emissions Construction - CO2 [tons]'][28] / gg_co2_causes['Emissions Construction - CO2 [tons]'][0])-1)*100,
           'Chemical Industry emissions - CO2 [tons]':((gg_co2_causes['Chemical Industry emissions - CO2 [tons]'][28] / gg_co2_causes['Chemical Industry emissions - CO2 [tons]'][0])-1)*100,
           'Energy sector emissions - CO2 [tons]':((gg_co2_causes['Energy sector emissions - CO2 [tons]'][28] / gg_co2_causes['Energy sector emissions - CO2 [tons]'][0])-1)*100,
           'Emissions Other industry - CO2 [tons]':((gg_co2_causes['Emissions Other industry - CO2 [tons]'][28] / gg_co2_causes['Emissions Other industry - CO2 [tons]'][0])-1)*100,
           'Refineries emissions - CO2 [tons]':((gg_co2_causes['Refineries emissions - CO2 [tons]'][28] / gg_co2_causes['Refineries emissions - CO2 [tons]'][0])-1)*100,
           'Agriculture emissions - CO2 [tons]':((gg_co2_causes['Agriculture emissions - CO2 [tons]'][28] / gg_co2_causes['Agriculture emissions - CO2 [tons]'][0])-1)*100
          }

# %%
new_row = {'Year':'Base 1990',
           'Drinking water supply emissions - CO2 [tons]':-51.96,
           'Consumer emissions - CO2 [tons]':-17.47,
           'Emissions Trade, Services and Government (HDO) - CO2 [tons]':-8.57,
           'Emissions WWTP - CO2 [tons]':30.84,
           'Emissions Traffic and transport - CO2 [tons]':24.82,
           'Emissions Waste Disposal - CO2 [tons]':138.32,
           'Emissions Construction - CO2 [tons]':40.16,
           'Chemical Industry emissions - CO2 [tons]':-12.32,
           'Energy sector emissions - CO2 [tons]':11.12,
           'Emissions Other industry - CO2 [tons]':-15.07,
           'Refineries emissions - CO2 [tons]':1.34,
           'Agriculture emissions - CO2 [tons]':5.10
          }

gg_co2_causes = gg_co2_causes.append(new_row, ignore_index = True)
gg_co2_causes
# Out:
#         Year  Drinking water supply emissions - CO2 [tons]  \
# 0       1990                                      14541.00
# 1       1995                                      14144.00
# 2       2000                                      31371.00
# 3       2005                                      22805.00
# 4       2010                                      26731.00
# 5       2015                                      10298.00
# 6       2016                                       8855.00
# 7       2017                                       8023.00
# 8       2018                                       6986.00
# 9  Base 1990                                        -51.96
#
#    Consumer emissions - CO2 [tons]  \
# 0                      22392114.00
# 1                      25068108.00
# 2                      22363194.00
# 3                      21752378.00
# 4                      25395682.00
# 5                      18632625.00
# 6                      19355662.00
# ...

# %%
new_row_piechart = {'Year':'2018',
           'Drinking water supply emissions - CO2 [tons]':0.004,
           'Consumer emissions - CO2 [tons]':10.30,
           'Emissions Trade, Services and Government (HDO) - CO2 [tons]':4.22,
           'Emissions WWTP - CO2 [tons]':0.46,
           'Emissions Traffic and transport - CO2 [tons]':23.06,
           'Emissions Waste Disposal - CO2 [tons]':5.42,
           'Emissions Construction - CO2 [tons]':0.37,
           'Chemical Industry emissions - CO2 [tons]':10.44,
           'Energy sector emissions - CO2 [tons]':26.396,
           'Emissions Other industry - CO2 [tons]':8.71,
           'Refineries emissions - CO2 [tons]':5.95,
           'Agriculture emissions - CO2 [tons]':4.67
          }

gg_co2_causes = gg_co2_causes.append(new_row_piechart, ignore_index = True)
gg_co2_causes
# Out:
#          Year  Drinking water supply emissions - CO2 [tons]  \
# 0        1990                                     14541.000
# 1        1995                                     14144.000
# 2        2000                                     31371.000
# 3        2005                                     22805.000
# 4        2010                                     26731.000
# 5        2015                                     10298.000
# 6        2016                                      8855.000
# 7        2017                                      8023.000
# 8        2018                                      6986.000
# 9   Base 1990                                       -51.960
# 10       2018                                         0.004
#
#     Consumer emissions - CO2 [tons]  \
# 0                       22392114.00
# 1                       25068108.00
# 2                       22363194.00
# 3                       21752378.00
# 4                       25395682.00
# ...

# %% [markdown]
# The biggest decrease in CO2 emissions is in Drinking Water Supply production,
# though it's not even 0.01% of total emissions in NL.
#
# The highest increase in CO2 emissions is in Waste Disposal Industry, who has more than doubled on 30 years !
#
# The Traffic and Transport emmissions are the highest part of total CO2 emissions in NL with +25%
# in 30 years. Weird for a country known for its many bikes and growing number of electric cars ...
#
#
# The 2nd and 3rd highest sector in emissions are actually some of the highest decrease (Consumers emissions, though the population is increasing & Chemical Industry)

# %%
renewable_energy
# Out:
#     Year        pop  biofuels_cons_ej  biofuels_prod_pj  biogeo_ej  \
# 0   1990  14.965442      0.000000e+00          0.000000   0.006700
# 1   1991  15.064522      0.000000e+00          0.000000   0.007500
# 2   1992  15.165856      0.000000e+00          0.000000   0.007520
# 3   1993  15.268005      0.000000e+00          0.000000   0.008630
# 4   1994  15.369121      0.000000e+00          0.000000   0.009390
# 5   1995  15.467852      0.000000e+00          0.000000   0.010170
# 6   1996  15.563252      0.000000e+00          0.000000   0.013160
# 7   1997  15.655482      3.470000e-18          0.000000   0.014630
# 8   1998  15.745650      0.000000e+00          0.000000   0.015903
# 9   1999  15.835525      0.000000e+00          0.000000   0.017883
# 10  2000  15.926188      0.000000e+00          0.000000   0.020132
# 11  2001  16.018112      0.000000e+00          0.000000   0.023427
# 12  2002  16.110355      0.000000e+00          0.000000   0.028692
# ...

# %%
#Let's have a look at the production of energy :

renewable_energy.columns
# Out:
# Index(['Year', 'pop', 'biofuels_cons_ej', 'biofuels_prod_pj', 'biogeo_ej',
#        'co2_mtco2', 'coalcons_ej', 'elect_twh', 'electbyfuel_coal',
#        'electbyfuel_gas', 'electbyfuel_oil', 'gascons_ej', 'gasprod_ej',
#        'gasreserves_tcm', 'hydro_ej', 'liqcons_kbd', 'nuclear_ej',
#        'oilcons_ej', 'primary_ej', 'primary_gj_pc', 'refcap_kbd',
#        'refthru_kbd', 'ren_power_ej', 'renewables_ej', 'solar_ej', 'wind_ej'],
#       dtype='object')

# %%
renewable_energy = renewable_energy[['Year', 'pop', 'biofuels_prod_pj', 'biogeo_ej',
       'elect_twh', 'electbyfuel_coal',
       'electbyfuel_gas', 'electbyfuel_oil', 'gasprod_ej',
       'hydro_ej', 'nuclear_ej', 'primary_ej', 'primary_gj_pc',
       'ren_power_ej', 'renewables_ej', 'solar_ej', 'wind_ej']]

renewable_energy
# Out:
#     Year        pop  biofuels_prod_pj  biogeo_ej   elect_twh  \
# 0   1990  14.965442          0.000000   0.006700   71.892000
# 1   1991  15.064522          0.000000   0.007500   74.282000
# 2   1992  15.165856          0.000000   0.007520   77.231000
# 3   1993  15.268005          0.000000   0.008630   76.992000
# 4   1994  15.369121          0.000000   0.009390   79.677000
# 5   1995  15.467852          0.000000   0.010170   81.063000
# 6   1996  15.563252          0.000000   0.013160   85.234000
# 7   1997  15.655482          0.000000   0.014630   86.659000
# 8   1998  15.745650          0.000000   0.015903   92.006273
# 9   1999  15.835525          0.000000   0.017883   87.617304
# 10  2000  15.926188          0.000000   0.020132   90.180577
# 11  2001  16.018112          0.000000   0.023427   94.072426
# 12  2002  16.110355          0.000000   0.028692   95.082892
# 13  2003  16.200948          0.000000   0.024985   98.140305
# ...

# %%
row_evol = {'Year':'Base 1990', 'pop':14.24, 'biofuels_prod_pj':7920.82, 'biogeo_ej':649.54,
       'elect_twh':68.36, 'electbyfuel_coal':-36.67,
       'electbyfuel_gas':94.39, 'electbyfuel_oil':-55.52, 'gasprod_ej':-55.70,
       'hydro_ej':-22.24, 'nuclear_ej':-0.48, 'primary_ej':7.15, 'primary_gj_pc':-6.20,
       'ren_power_ej':2635.76, 'renewables_ej':3053.79, 'solar_ej':462490, 'wind_ej':18138.93}

# %%
renewable_energy = renewable_energy.append(row_evol, ignore_index = True)
renewable_energy
# Out:
#          Year        pop  biofuels_prod_pj   biogeo_ej   elect_twh  \
# 0        1990  14.965442          0.000000    0.006700   71.892000
# 1        1991  15.064522          0.000000    0.007500   74.282000
# 2        1992  15.165856          0.000000    0.007520   77.231000
# 3        1993  15.268005          0.000000    0.008630   76.992000
# 4        1994  15.369121          0.000000    0.009390   79.677000
# 5        1995  15.467852          0.000000    0.010170   81.063000
# 6        1996  15.563252          0.000000    0.013160   85.234000
# 7        1997  15.655482          0.000000    0.014630   86.659000
# 8        1998  15.745650          0.000000    0.015903   92.006273
# 9        1999  15.835525          0.000000    0.017883   87.617304
# 10       2000  15.926188          0.000000    0.020132   90.180577
# 11       2001  16.018112          0.000000    0.023427   94.072426
# 12       2002  16.110355          0.000000    0.028692   95.082892
# ...

# %% [markdown]
# Use of fossil energy like coal, oil, and nuclear has decreased while, even if the amount product if far from equaling the total amount of energy produced for the country, the production of renewable energy from biofuels, geothermy, solar and wind has largely increased compared to 1990.
#
# The population seems to react well to climate change as the use of primary energy per capita is decreasing.

# %% [markdown]
# In 1990 : 6,11ej of energy produced => 0,24% of energy from renewable ressources (0,0148ej)
# In 2019 : 5,81ej of energy produced => 8,54% of energy from renewable ressources (0,496ej)
#
# Less energy has been produced for an increased population which meansthat the country might be more energy efficient (use of LEDs, better electronic equipment...).
#
# Even though the energy from renewable ressources is increasing, it is still a minority of the ressources used to aliment the country.
