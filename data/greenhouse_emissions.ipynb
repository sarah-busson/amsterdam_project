# %% [markdown]
# The goal of this dataset is to collect all informations regarding the production of energy
# from renewable ressources in the Netherlands and/or Amsterdam,
# according to the availability of the databases

# %%
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\sarah\\Documents\\IRONHACK\\The_Amsterdam_Project\\NL_greenhouse90_99.csv')
#data.head()

data2 = pd.read_csv('C:\\Users\\sarah\\Documents\\IRONHACK\\The_Amsterdam_Project\\NL_greenhouse00_18.csv')
#data2.head()

# %%
data2.reset_index()
data.reset_index()
# Out:
#                                                 index        1990        1991  \
# 0   Totaal bekende CO2-uitstoot (gas, elektr., war...         NaN         NaN
# 1   Totaal bekende CO2-uitstoot exclusief CO2-uits...         NaN         NaN
# 2   CO2-uitstoot Gebouwde Omgeving (gas, elektr. e...         NaN         NaN
# 3   CO2-uitstoot Verkeer en vervoer incl. auto(sne...  32657895.0  33067134.0
# 4   CO2-uitstoot Industrie, Energie, Afval en Wate...         NaN         NaN
# ..                                                ...         ...         ...
# 76  Uitstoot (CO2-eq.) Totaal Methaan (CH4) volgen...         NaN         NaN
# 77  Uitstoot (CO2-eq.) Totaal PFK116 volgens IPCC ...         NaN         NaN
# 78  Uitstoot (CO2-eq.) Totaal PFK14 volgens IPCC A...         NaN         NaN
# 79  Uitstoot (CO2-eq.) Totaal Zwavelhexafluoride (...         NaN         NaN
# 80  Uitstoot (CO2-eq.) Totaal F-gassen (HFK's, SF6...         NaN         NaN
#
# ...

# %%
ge = data.merge(data2, on='1999', left_index = True, right_index = True, copy = False)
ge.head()
# Out:
#                                                           1990        1991  \
# Totaal bekende CO2-uitstoot (gas, elektr., warm...         NaN         NaN
# Totaal bekende CO2-uitstoot exclusief CO2-uitst...         NaN         NaN
# CO2-uitstoot Gebouwde Omgeving (gas, elektr. en...         NaN         NaN
# CO2-uitstoot Verkeer en vervoer incl. auto(snel...  32657895.0  33067134.0
# CO2-uitstoot Industrie, Energie, Afval en Water...         NaN         NaN
#
#                                                           1992        1993  \
# Totaal bekende CO2-uitstoot (gas, elektr., warm...         NaN         NaN
# Totaal bekende CO2-uitstoot exclusief CO2-uitst...         NaN         NaN
# CO2-uitstoot Gebouwde Omgeving (gas, elektr. en...         NaN         NaN
# CO2-uitstoot Verkeer en vervoer incl. auto(snel...  33476372.0  33885611.0
# CO2-uitstoot Industrie, Energie, Afval en Water...         NaN         NaN
#
# ...

# %%
ge = ge.transpose().reset_index()

# %%
ge
# Out:
#    index  \
# 0   1990
# 1   1991
# 2   1992
# 3   1993
# 4   1994
# 5   1995
# 6   1996
# 7   1997
# 8   1998
# 9   1999
# 10  2000
# 11  2001
# 12  2002
# 13  2003
# 14  2004
# 15  2005
# 16  2006
# 17  2007
# 18  2008
# 19  2009
# 20  2010
# 21  2011
# 22  2012
# 23  2013
# 24  2014
# 25  2015
# 26  2016
# 27  2017
# 28  2018
#
#     Totaal bekende CO2-uitstoot (gas, elektr., warmte, voertuigbrandstoffen) [ton]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# ...

# %%
ge.columns
# Out:
# Index(['index',
#        'Totaal bekende CO2-uitstoot (gas, elektr., warmte, voertuigbrandstoffen) [ton]',
#        'Totaal bekende CO2-uitstoot exclusief CO2-uitstoot auto(snel)wegen [ton]',
#        'CO2-uitstoot Gebouwde Omgeving (gas, elektr. en warmte, tier 3/tier 2) [ton]',
#        'CO2-uitstoot Verkeer en vervoer incl. auto(snel)wegen, excl. elektr. railverkeer (scope 1, tier 1) [ton]',
#        'CO2-uitstoot Industrie, Energie, Afval en Water (gas en elektr., tier 3) [ton]',
#        'CO2-uitstoot Landbouw, bosbouw en visserij, SBI A (gas, elektr., tier 3) [ton]',
#        'CO2-uitstoot Bedrijven en instellingen excl. gasgebruik energieproductie (gas en elektriciteit) [ton]',
#        'CO2-uitstoot Woningen, temperatuurgecorrigeerd (sjv gas en elektr., tier 3 en warmte, tier 2) [ton]',
#        'CO2-uitstoot t.g.v. gasverbruik [ton]',
#        'CO2-uitstoot t.g.v. elektriciteitsgebruik [ton]',
# ...

# %%
ge_light = ge[['index',
       'Totaal bekende CO2-uitstoot (gas, elektr., warmte, voertuigbrandstoffen) [ton]',
       'Totaal bekende CO2-uitstoot exclusief CO2-uitstoot auto(snel)wegen [ton]',
       'CO2-uitstoot Gebouwde Omgeving (gas, elektr. en warmte, tier 3/tier 2) [ton]',
       'CO2-uitstoot Verkeer en vervoer incl. auto(snel)wegen, excl. elektr. railverkeer (scope 1, tier 1) [ton]',
       'CO2-uitstoot Industrie, Energie, Afval en Water (gas en elektr., tier 3) [ton]',
       'CO2-uitstoot Landbouw, bosbouw en visserij, SBI A (gas, elektr., tier 3) [ton]',
       'CO2-uitstoot Bedrijven en instellingen excl. gasgebruik energieproductie (gas en elektriciteit) [ton]',
       'CO2-uitstoot Woningen, temperatuurgecorrigeerd (sjv gas en elektr., tier 3 en warmte, tier 2) [ton]',
       'CO2-uitstoot t.g.v. gasverbruik [ton]',
       'CO2-uitstoot t.g.v. elektriciteitsgebruik [ton]',
       'Totale CO2-uitstoot volgens Emissieregistratie (alle emissieoorzaken) [ton]',
       'Totale CO2-uitstoot excl. opwekking elektriciteit volgens ER (alle emissieoorzaken) [ton]',
       'Uitstoot Drinkwatervoorziening - CO2 [ton]',
       'Uitstoot Consumenten - CO2 [ton]',
       'Uitstoot Handel, Diensten en Overheid (HDO) - CO2 [ton]',
       'Uitstoot RWZI - CO2 [ton]',
       'Uitstoot Consumenten - Energiegebruik Consumenten - CO2 [ton]',
       'Uitstoot Consumenten - Indirecte emissies broeikasgassen Consumenten - CO2 [ton]',
       'Uitstoot Consumenten - Productgebruik Consumenten - CO2 [ton]',
       'Uitstoot Drinkwatervoorziening - Drinkwaterbedrijven - CO2 [ton]',
       'Uitstoot Handel, Diensten en Overheid (HDO) - Energiegebruik en processen - CO2 [ton]',
       'Uitstoot Handel, Diensten en Overheid (HDO) - Indirecte emissies broeikasgassen - CO2 [ton]',
       'Uitstoot RWZI - Energiegebruik en processen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Binnenscheepvaart - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Luchtvaart - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Mobiele werktuigen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Railverkeer - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Recreatievaart - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Smeermiddelengebruik-verkeer - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Visserij - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Wegverkeer - niet uitlaatgassen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Wegverkeer - uitlaatgassen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Zeescheepvaart - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Zeescheepvaart NCP (inclusief ankerliggers) - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Zeescheepvaart varend op Nederlands grondgebied - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Zeescheepvaart stilliggend - CO2 [ton]',
       'Uitstoot Afvalverwijdering - CO2 [ton]', 'Uitstoot Bouw - CO2 [ton]',
       'Uitstoot Chemische Industrie - CO2 [ton]',
       'Uitstoot Energiesector - CO2 [ton]',
       'Uitstoot Overige industrie - CO2 [ton]',
       'Uitstoot Raffinaderijen - CO2 [ton]', 'Uitstoot Landbouw - CO2 [ton]',
       'Uitstoot Landbouw - Energiegebruik Landbouw - CO2 [ton]',
       'Uitstoot Landbouw - Indirecte emissies broeikasgassen Landbouw - CO2 [ton]',
       'Uitstoot Landbouw - Landbouwbedrijven - CO2 [ton]',
       'Uitstoot Landbouw - Productgebruik Landbouw - CO2 [ton]',
       'Uitstoot Totaal Methaan (CH4) [kg]',
       'Uitstoot Totaal Lachgas (N2O) [kg]', 'Uitstoot Totaal HFK 32 [kg]',
       'Uitstoot Totaal HFK 23 [kg]', 'Uitstoot Totaal HFK 152A [kg]',
       'Uitstoot Totaal HFK 143A [kg]', 'Uitstoot Totaal HFK 134A [kg]',
       'Uitstoot Totaal HFK 125 [kg]',
       'Uitstoot Totaal Zwavelhexafluoride (SF6) [kg]',
       'Totaal uitstoot overige broeikasgassen (CO2-eq.) volgens IPCC AR5 [ton CO2-equivalent]',
       'Uitstoot (CO2-eq.) Totaal Methaan (CH4) volgens IPCC AR5 [ton CO2-equivalent]',
       "Uitstoot (CO2-eq.) Totaal F-gassen (HFK's, SF6) volgens IPCC AR5 [ton CO2-equivalent]",
       'Uitstoot (CO2-eq.) Totaal Lachgas (N2O) volgens IPCC AR5 [ton CO2-equivalent]',
       'Uitstoot (CO2-eq.) Totaal HFK 32 volgens IPCC AR5 [ton CO2-equivalent]',
       'Uitstoot (CO2-eq.) Totaal HFK 23 volgens IPCC AR5 [ton CO2-equivalent]',
       'Uitstoot (CO2-eq.) Totaal HFK 152A volgens IPCC AR5 [ton CO2-equivalent]',
       'Uitstoot (CO2-eq.) Totaal HFK 14 volgens IPCC AR5 [ton CO2-equivalent]',
       'Uitstoot (CO2-eq.) Totaal HFK 134A volgens IPCC AR5 [ton CO2-equivalent]',
       'Uitstoot (CO2-eq.) Totaal HFK 125 volgens IPCC AR5 [ton CO2-equivalent]',
       'Uitstoot (CO2-eq.) Totaal Zwavelhexafluoride (SF6) volgens IPCC AR5 [ton CO2-equivalent]']]

# %%
ge_light.columns = ['Year',
       'Totaal bekende CO2-uitstoot (gas, elektr., warmte, voertuigbrandstoffen) [ton]',
       'Totaal bekende CO2-uitstoot exclusief CO2-uitstoot auto(snel)wegen [ton]',
       'CO2-uitstoot Gebouwde Omgeving (gas, elektr. en warmte, tier 3/tier 2) [ton]',
       'CO2-uitstoot Verkeer en vervoer incl. auto(snel)wegen, excl. elektr. railverkeer (scope 1, tier 1) [ton]',
       'CO2-uitstoot Industrie, Energie, Afval en Water (gas en elektr., tier 3) [ton]',
       'CO2-uitstoot Landbouw, bosbouw en visserij, SBI A (gas, elektr., tier 3) [ton]',
       'CO2-uitstoot Bedrijven en instellingen excl. gasgebruik energieproductie (gas en elektriciteit) [ton]',
       'CO2-uitstoot Woningen, temperatuurgecorrigeerd (sjv gas en elektr., tier 3 en warmte, tier 2) [ton]',
       'CO2-uitstoot t.g.v. gasverbruik [ton]',
       'CO2-uitstoot t.g.v. elektriciteitsgebruik [ton]',
       'Totale CO2-uitstoot volgens Emissieregistratie (alle emissieoorzaken) [ton]',
       'Totale CO2-uitstoot excl. opwekking elektriciteit volgens ER (alle emissieoorzaken) [ton]',
       'Uitstoot Drinkwatervoorziening - CO2 [ton]',
       'Uitstoot Consumenten - CO2 [ton]',
       'Uitstoot Handel, Diensten en Overheid (HDO) - CO2 [ton]',
       'Uitstoot RWZI - CO2 [ton]',
       'Uitstoot Consumenten - Energiegebruik Consumenten - CO2 [ton]',
       'Uitstoot Consumenten - Indirecte emissies broeikasgassen Consumenten - CO2 [ton]',
       'Uitstoot Consumenten - Productgebruik Consumenten - CO2 [ton]',
       'Uitstoot Drinkwatervoorziening - Drinkwaterbedrijven - CO2 [ton]',
       'Uitstoot Handel, Diensten en Overheid (HDO) - Energiegebruik en processen - CO2 [ton]',
       'Uitstoot Handel, Diensten en Overheid (HDO) - Indirecte emissies broeikasgassen - CO2 [ton]',
       'Uitstoot RWZI - Energiegebruik en processen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Binnenscheepvaart - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Luchtvaart - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Mobiele werktuigen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Railverkeer - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Recreatievaart - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Smeermiddelengebruik-verkeer - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Visserij - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Wegverkeer - niet uitlaatgassen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Wegverkeer - uitlaatgassen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Zeescheepvaart - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Zeescheepvaart NCP (inclusief ankerliggers) - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Zeescheepvaart varend op Nederlands grondgebied - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Zeescheepvaart stilliggend - CO2 [ton]',
       'Uitstoot Afvalverwijdering - CO2 [ton]', 'Uitstoot Bouw - CO2 [ton]',
       'Uitstoot Chemische Industrie - CO2 [ton]',
       'Uitstoot Energiesector - CO2 [ton]',
       'Uitstoot Overige industrie - CO2 [ton]',
       'Uitstoot Raffinaderijen - CO2 [ton]', 'Uitstoot Landbouw - CO2 [ton]',
       'Uitstoot Landbouw - Energiegebruik Landbouw - CO2 [ton]',
       'Uitstoot Landbouw - Indirecte emissies broeikasgassen Landbouw - CO2 [ton]',
       'Uitstoot Landbouw - Landbouwbedrijven - CO2 [ton]',
       'Uitstoot Landbouw - Productgebruik Landbouw - CO2 [ton]',
       'Uitstoot Totaal Methaan (CH4) [kg]',
       'Uitstoot Totaal Lachgas (N2O) [kg]', 'Uitstoot Totaal HFK 32 [kg]',
       'Uitstoot Totaal HFK 23 [kg]', 'Uitstoot Totaal HFK 152A [kg]',
       'Uitstoot Totaal HFK 143A [kg]', 'Uitstoot Totaal HFK 134A [kg]',
       'Uitstoot Totaal HFK 125 [kg]',
       'Uitstoot Totaal Zwavelhexafluoride (SF6) [kg]',
       'Totaal uitstoot overige broeikasgassen (CO2-eq.)[ton CO2-equivalent]',
       'Totaal Methaan (CH4)[ton CO2-equivalent]',
       "Totaal F-gassen (HFK's, SF6)[ton CO2-equivalent]",
       'Totaal Lachgas (N2O)[ton CO2-equivalent]',
       'Totaal HFK 32 [ton CO2-equivalent]',
       'Totaal HFK 23 [ton CO2-equivalent]',
       'Totaal HFK 152A [ton CO2-equivalent]',
       'Totaal HFK 14 [ton CO2-equivalent]',
       'Totaal HFK 134A [ton CO2-equivalent]',
       'Totaal HFK 125 [ton CO2-equivalent]',
       'Totaal Zwavelhexafluoride (SF6)[ton CO2-equivalent]']

# %%
ge_light = ge_light[['Year',
       'Totaal bekende CO2-uitstoot (gas, elektr., warmte, voertuigbrandstoffen) [ton]',
       'Totaal bekende CO2-uitstoot exclusief CO2-uitstoot auto(snel)wegen [ton]',
       'CO2-uitstoot Gebouwde Omgeving (gas, elektr. en warmte, tier 3/tier 2) [ton]',
       'CO2-uitstoot Verkeer en vervoer incl. auto(snel)wegen, excl. elektr. railverkeer (scope 1, tier 1) [ton]',
       'CO2-uitstoot Industrie, Energie, Afval en Water (gas en elektr., tier 3) [ton]',
       'CO2-uitstoot Landbouw, bosbouw en visserij, SBI A (gas, elektr., tier 3) [ton]',
       'CO2-uitstoot Bedrijven en instellingen excl. gasgebruik energieproductie (gas en elektriciteit) [ton]',
       'CO2-uitstoot Woningen, temperatuurgecorrigeerd (sjv gas en elektr., tier 3 en warmte, tier 2) [ton]',
       'CO2-uitstoot t.g.v. gasverbruik [ton]',
       'CO2-uitstoot t.g.v. elektriciteitsgebruik [ton]',
       'Totale CO2-uitstoot volgens Emissieregistratie (alle emissieoorzaken) [ton]',
       'Totale CO2-uitstoot excl. opwekking elektriciteit volgens ER (alle emissieoorzaken) [ton]',
       'Uitstoot Drinkwatervoorziening - CO2 [ton]',
       'Uitstoot Consumenten - CO2 [ton]',
       'Uitstoot Handel, Diensten en Overheid (HDO) - CO2 [ton]',
       'Uitstoot RWZI - CO2 [ton]',
       'Uitstoot Consumenten - Energiegebruik Consumenten - CO2 [ton]',
       'Uitstoot Consumenten - Indirecte emissies broeikasgassen Consumenten - CO2 [ton]',
       'Uitstoot Consumenten - Productgebruik Consumenten - CO2 [ton]',
       'Uitstoot Drinkwatervoorziening - Drinkwaterbedrijven - CO2 [ton]',
       'Uitstoot Handel, Diensten en Overheid (HDO) - Energiegebruik en processen - CO2 [ton]',
       'Uitstoot Handel, Diensten en Overheid (HDO) - Indirecte emissies broeikasgassen - CO2 [ton]',
       'Uitstoot RWZI - Energiegebruik en processen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Binnenscheepvaart - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Luchtvaart - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Mobiele werktuigen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Railverkeer - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Recreatievaart - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Smeermiddelengebruik-verkeer - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Visserij - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Wegverkeer - niet uitlaatgassen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Wegverkeer - uitlaatgassen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Zeescheepvaart - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Zeescheepvaart NCP (inclusief ankerliggers) - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Zeescheepvaart varend op Nederlands grondgebied - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - Zeescheepvaart stilliggend - CO2 [ton]',
       'Uitstoot Afvalverwijdering - CO2 [ton]', 'Uitstoot Bouw - CO2 [ton]',
       'Uitstoot Chemische Industrie - CO2 [ton]',
       'Uitstoot Energiesector - CO2 [ton]',
       'Uitstoot Overige industrie - CO2 [ton]',
       'Uitstoot Raffinaderijen - CO2 [ton]', 'Uitstoot Landbouw - CO2 [ton]',
       'Uitstoot Landbouw - Energiegebruik Landbouw - CO2 [ton]',
       'Uitstoot Landbouw - Indirecte emissies broeikasgassen Landbouw - CO2 [ton]',
       'Uitstoot Landbouw - Landbouwbedrijven - CO2 [ton]',
       'Uitstoot Landbouw - Productgebruik Landbouw - CO2 [ton]',
       'Totaal uitstoot overige broeikasgassen (CO2-eq.)[ton CO2-equivalent]',
       'Totaal Methaan (CH4)[ton CO2-equivalent]',
       "Totaal F-gassen (HFK's, SF6)[ton CO2-equivalent]",
       'Totaal Lachgas (N2O)[ton CO2-equivalent]',
       'Totaal HFK 32 [ton CO2-equivalent]',
       'Totaal HFK 23 [ton CO2-equivalent]',
       'Totaal HFK 152A [ton CO2-equivalent]',
       'Totaal HFK 14 [ton CO2-equivalent]',
       'Totaal HFK 134A [ton CO2-equivalent]',
       'Totaal HFK 125 [ton CO2-equivalent]',
       'Totaal Zwavelhexafluoride (SF6)[ton CO2-equivalent]']]

# %%
ge_other = ge_light[['Year','Totaal uitstoot overige broeikasgassen (CO2-eq.)[ton CO2-equivalent]',
       'Totaal Methaan (CH4)[ton CO2-equivalent]',
       "Totaal F-gassen (HFK's, SF6)[ton CO2-equivalent]",
       'Totaal Lachgas (N2O)[ton CO2-equivalent]']]

ge_other.columns = ['Year','Total emissions of other greenhouse gases',
        'Total Methane (CH4)',
        "Total F-Gases (HFCs, SF6)",
        'Total Nitrous Oxide (N2O)']

ge_other_clean = ge_other.drop([i for i in range(25)])
#Emission of greenhouse gases other than CO2 in [ton CO2 equivalent]
ge_other_clean
# Out:
#     Year  Total emissions of other greenhouse gases  Total Methane (CH4)  \
# 25  2015                                 32545553.0           21980252.0
# 26  2016                                 31936050.0           22086896.0
# 27  2017                                 32117170.0           21715493.0
# 28  2018                                 31096259.0           21017804.0
#
#     Total F-Gases (HFCs, SF6)  Total Nitrous Oxide (N2O)
# 25                  2292734.0                  8272567.0
# 26                  1881665.0                  7967488.0
# 27                  1843693.0                  8557984.0
# 28                  1881584.0                  8196871.0

# %%
ge_co2 = ge_light[['Year',
       'Totaal bekende CO2-uitstoot (gas, elektr., warmte, voertuigbrandstoffen) [ton]',
       'Totaal bekende CO2-uitstoot exclusief CO2-uitstoot auto(snel)wegen [ton]',
       'Totale CO2-uitstoot volgens Emissieregistratie (alle emissieoorzaken) [ton]',
       'Totale CO2-uitstoot excl. opwekking elektriciteit volgens ER (alle emissieoorzaken) [ton]',
       'Uitstoot Drinkwatervoorziening - CO2 [ton]',
       'Uitstoot Consumenten - CO2 [ton]',
       'Uitstoot Handel, Diensten en Overheid (HDO) - CO2 [ton]',
       'Uitstoot RWZI - CO2 [ton]',
       'Uitstoot Consumenten - Energiegebruik Consumenten - CO2 [ton]',
       'Uitstoot Consumenten - Indirecte emissies broeikasgassen Consumenten - CO2 [ton]',
       'Uitstoot Consumenten - Productgebruik Consumenten - CO2 [ton]',
       'Uitstoot Drinkwatervoorziening - Drinkwaterbedrijven - CO2 [ton]',
       'Uitstoot Handel, Diensten en Overheid (HDO) - Energiegebruik en processen - CO2 [ton]',
       'Uitstoot Handel, Diensten en Overheid (HDO) - Indirecte emissies broeikasgassen - CO2 [ton]',
       'Uitstoot RWZI - Energiegebruik en processen - CO2 [ton]',
       'Uitstoot Verkeer en vervoer - CO2 [ton]',
       'Uitstoot Afvalverwijdering - CO2 [ton]', 
       'Uitstoot Bouw - CO2 [ton]',
       'Uitstoot Chemische Industrie - CO2 [ton]',
       'Uitstoot Energiesector - CO2 [ton]',
       'Uitstoot Overige industrie - CO2 [ton]',
       'Uitstoot Raffinaderijen - CO2 [ton]', 
       'Uitstoot Landbouw - CO2 [ton]']]

# %%
sum1 = (ge_light['Uitstoot Landbouw - Energiegebruik Landbouw - CO2 [ton]'] + 
        ge_light['Uitstoot Landbouw - Indirecte emissies broeikasgassen Landbouw - CO2 [ton]'] +
        ge_light['Uitstoot Landbouw - Landbouwbedrijven - CO2 [ton]'] +
        ge_light['Uitstoot Landbouw - Productgebruik Landbouw - CO2 [ton]'])

ge_light['Sum Uitstoot Landbouw'] = sum1

ge_light[['Sum Uitstoot Landbouw', 'Uitstoot Landbouw - CO2 [ton]',
       'Uitstoot Landbouw - Energiegebruik Landbouw - CO2 [ton]',
       'Uitstoot Landbouw - Indirecte emissies broeikasgassen Landbouw - CO2 [ton]',
       'Uitstoot Landbouw - Landbouwbedrijven - CO2 [ton]',
       'Uitstoot Landbouw - Productgebruik Landbouw - CO2 [ton]']]

ge_co2_agri = ge_light[['Uitstoot Landbouw - CO2 [ton]']]

#It confirms the fact that some colums are the sum of their sub-columns. 
#Which is gonna help me filter this dataframe.

# %%
#ge_co2 = ge_co2.set_index('Year').transpose()
ge_co2.columns

null_co2 = ge_co2.isnull().sum()
null_co2[null_co2 == 23]
ge_co2_clean = ge_co2.drop(list(null_co2[null_co2 == 23].index), axis=1)
ge_co2_clean
# Out:
#     Year  \
# 0   1990
# 1   1991
# 2   1992
# 3   1993
# 4   1994
# 5   1995
# 6   1996
# 7   1997
# 8   1998
# 9   1999
# 10  2000
# 11  2001
# 12  2002
# 13  2003
# 14  2004
# 15  2005
# 16  2006
# 17  2007
# 18  2008
# 19  2009
# 20  2010
# 21  2011
# 22  2012
# 23  2013
# 24  2014
# 25  2015
# 26  2016
# 27  2017
# 28  2018
#
#     Totaal bekende CO2-uitstoot (gas, elektr., warmte, voertuigbrandstoffen) [ton]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# ...

# %%
ge_co2_clean.columns = ['Year',
                        'Total known CO2 emissions (gas, electricity, heat, vehicle fuels) [tons]',
                        'Total known CO2 emissions excluding CO2 emissions from car (motor) weighing [tons]',
                        'Total CO2 emissions according to Emission Registration (all emission causes) [tons]',
                        'Total CO2 emissions excluding electricity generation according to ER (all emission causes) [tons]',
                        'Drinking water supply emissions - CO2 [tons]',
                        'Consumer emissions - CO2 [tons]',
                        'Emissions Trade, Services and Government (HDO) - CO2 [tons]',
                        'Emissions WWTP - CO2 [tons]',
                        'Emission Consumers - Energy use Consumers - CO2 [tons]',
                        'Emissions Consumers - Indirect emissions greenhouse gases Consumers - CO2 [tons]',
                        'Emission Consumers - Product use Consumers - CO2 [tons]',
                        'Drinking water supply - Drinking water companies - CO2 [tons]',
                        'Emissions Trade, Services and Government (HDO) - Energy use and processes - CO2 [tons]',
                        'Emissions Trade, Services and Government (HDO) - Indirect emissions of greenhouse gases - CO2 [tons]',
                        'Emissions WWTP - Energy use and processes - CO2 [tons]',
                        'Emissions Traffic and transport - CO2 [tons]',
                        'Emissions Waste Disposal - CO2 [tons]', 
                        'Emissions Construction - CO2 [tons]',
                        'Chemical Industry emissions - CO2 [tons]',
                        'Energy sector emissions - CO2 [tons]',
                        'Emissions Other industry - CO2 [tons]',
                        'Refineries emissions - CO2 [tons]', 
                        'Agriculture emissions - CO2 [tons]']

# %%
ge_co2_clean.to_csv('C:\\Users\\sarah\\Documents\\IRONHACK\\The_Amsterdam_Project\\greenhouse_CO2.txt', index=False)
ge_other_clean.to_csv('C:\\Users\\sarah\\Documents\\IRONHACK\\The_Amsterdam_Project\\greenhouse_others.txt', index=False)
